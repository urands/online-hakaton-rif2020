# %%
import pandas as pd

# %%
good = pd.read_csv('good.csv', sep=';', nrows=None, header=None)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-13-847900d1f37c> in <module>
# ----> 1 good = pd.read_csv('good.csv', sep=';', nrows=None, header=None)
#       2
#
# c:\dev\python38\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
'10008225;109316, г.Москва, ул. Мельникова, дом 3;house;РОССИЯ;МОСКВА;МОСКВА;;;;Улица;МЕЛЬНИКОВА;3;;;;'
a = '10008226;109316, г.Москва, ул. Сосинская, дом 43;house;РОССИЯ;МОСКВА;МОСКВА;;;;Улица;СОСИНСКАЯ;43;;;;'
b = '10008227;109316, г.Москва, ул. Стройковская, дом 10А;house;РОССИЯ;МОСКВА;МОСКВА;;;;Улица;СТРОЙКОВСКАЯ;10А;;;;'

# %%
pd.DataFrame(a.split(';'))
# Out:
#                                           0
# 0                                  10008226
# 1   109316, г.Москва, ул. Сосинская, дом 43
# 2                                     house
# 3                                    РОССИЯ
# 4                                    МОСКВА
# 5                                    МОСКВА
# 6
# 7
# 8
# 9                                     Улица
# 10                                СОСИНСКАЯ
# 11                                       43
# 12
# 13
# 14
# 15

# %%
pd.DataFrame(b.split(';'))
# Out:
#                                               0
# 0                                      10008227
# 1   109316, г.Москва, ул. Стройковская, дом 10А
# 2                                         house
# 3                                        РОССИЯ
# 4                                        МОСКВА
# 5                                        МОСКВА
# 6
# 7
# 8
# 9                                         Улица
# 10                                 СТРОЙКОВСКАЯ
# 11                                          10А
# 12
# 13
# 14
# 15
